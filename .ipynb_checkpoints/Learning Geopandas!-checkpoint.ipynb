# %%
import geopandas as gd

pa_gdf = gd.read_file("JointSubmissionShape.dbf")

pa_gdf.plot()

# %%
pa2_gdf = gd.read_file("WOLF_MAP_SUBMISSION.DBF")
pa2_gdf.plot()

# %%
pa2_gdf = gd.read_file("Judges_Districts.dbf")
pa2_gdf.plot()
